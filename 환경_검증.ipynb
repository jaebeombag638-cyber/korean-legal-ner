# %% [markdown]
# # 기술 스택 환경 검증
# 각 셀을 순서대로 실행해서 모든 라이브러리가 정상 작동하는지 확인합니다.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'문자': ['정상 문자입니다', '스미싱 의심 문자'], '레이블': [0, 1]})
print(f'pandas {pd.__version__}, numpy {np.__version__}')
df
# Out:
# pandas 2.3.3, numpy 2.2.6
#           문자  레이블
# 0   정상 문자입니다    0
# 1  스미싱 의심 문자    1

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots(figsize=(5, 3))
sns.barplot(data=df, x='문자', y='레이블', ax=ax)
ax.set_title('레이블 분포')
plt.tight_layout()
plt.show()
print(f'matplotlib {matplotlib.__version__}, seaborn {sns.__version__}')
# Out:
# matplotlib 3.10.9, seaborn 0.13.2

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import sklearn

texts = ['정상 문자입니다', '스미싱 의심 문자', '당첨되셨습니다 클릭', '안녕하세요']
labels = [0, 1, 1, 0]

vec = TfidfVectorizer()
X = vec.fit_transform(texts)
model = LogisticRegression()
model.fit(X, labels)
print(f'scikit-learn {sklearn.__version__}')
print('예측:', model.predict(X))
# Out:
# scikit-learn 1.7.2
# 예측: [0 1 1 0]

# %%
import os
os.environ['JAVA_HOME'] = r'C:\Program Files\Eclipse Adoptium\jdk-17.0.19.10-hotspot'
os.environ['PATH'] = r'C:\Program Files\Eclipse Adoptium\jdk-17.0.19.10-hotspot\bin' + os.pathsep + os.environ.get('PATH', '')

from konlpy.tag import Okt

okt = Okt()
text = '스미싱 탐지 프로젝트를 시작합니다'
print('형태소:', okt.morphs(text))
print('명사:', okt.nouns(text))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 10
#       6     jpype.startJVM(r'C:\Program Files\Eclipse Adoptium\jdk-17.0.19.10-hotspot\bin\server\jvm.dll')
#       8 from konlpy.tag import Okt
# ---> 10 okt = Okt()
#      11 text = '스미싱 탐지 프로젝트를 시작합니다'
#      12 print('형태소:', okt.morphs(text))
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\konlpy\tag\_okt.py:54, in Okt.__init__(self, jvmpath, max_heap_size)
#      51     jvm.init_jvm(jvmpath, max_heap_size)
#      53 oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
# ---> 54 OktInterfaceJavaClass = oktJavaPackage.OktInterface
#      55 self.jki = OktInterfaceJavaClass()
#      56 self.tagset = utils.read_json('%s/data/tagset/twitter.json' % utils.installpath)
#
# AttributeError: Java package 'kr.lucypark.okt' is not valid

# %% [markdown]
# ## 모든 셀이 오류 없이 실행되면 환경 세팅 완료입니다.
